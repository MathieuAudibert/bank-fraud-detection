# %%
try:
    import pandas as pd
except ImportError:
    # %pip install pandas
    import pandas as pd

import sqlite3

conn = sqlite3.connect('../scripts/bank.db')

customers = pd.read_sql_query("SELECT * FROM Customers", conn)
accounts = pd.read_sql_query("SELECT * FROM Accounts", conn)
transactions = pd.read_sql_query("SELECT * FROM Transactions", conn)

print(customers)
print(accounts)
print(transactions)

def detect_fraud(transactions, threshold=1000):
    potential_fraud = transactions[(transactions['transaction_type'] == 'Withdrawal') & (transactions['amount'] > threshold)]
    return potential_fraud

potential_fraud = detect_fraud(transactions)
print("Potential Fraudulent Transactions:")
print(potential_fraud)

total_transactions = len(transactions)
total_fraud = len(potential_fraud)
fraud_percentage = (total_fraud / total_transactions) * 100
total_fraud_amount = potential_fraud['amount'].sum()

print(f"Total Transactions: {total_transactions}")
print(f"Total Fraudulent Transactions: {total_fraud}")
print(f"Percentage of Fraudulent Transactions: {fraud_percentage:.2f}%")
print(f"Total Fraudulent Amount: ${total_fraud_amount:.2f}")

conn.close
# Out:
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\Mathieu\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting pandas
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.0.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.9 kB 330.3 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.9 kB 495.5 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 544.7 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mathieu\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\mathieu\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# Downloading numpy-2.0.0-cp312-cp312-win_amd64.whl (16.2 MB)
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#     --------------------------------------- 0.2/16.2 MB 6.9 MB/s eta 0:00:03
#    - -------------------------------------- 0.5/16.2 MB 6.3 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/16.2 MB 6.7 MB/s eta 0:00:03
#    --- ------------------------------------ 1.2/16.2 MB 7.1 MB/s eta 0:00:03
#    --- ------------------------------------ 1.6/16.2 MB 7.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.9/16.2 MB 7.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.3/16.2 MB 7.4 MB/s eta 0:00:02
#    ------ --------------------------------- 2.7/16.2 MB 7.4 MB/s eta 0:00:02
#    ------- -------------------------------- 3.0/16.2 MB 7.4 MB/s eta 0:00:02
#    -------- ------------------------------- 3.4/16.2 MB 7.5 MB/s eta 0:00:02
#    --------- ------------------------------ 3.7/16.2 MB 7.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.1/16.2 MB 7.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.4/16.2 MB 7.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.8/16.2 MB 7.4 MB/s eta 0:00:02
#    ------------ --------------------------- 5.2/16.2 MB 7.5 MB/s eta 0:00:02
#    ------------- -------------------------- 5.6/16.2 MB 7.7 MB/s eta 0:00:02
#    -------------- ------------------------- 5.9/16.2 MB 7.7 MB/s eta 0:00:02
#    --------------- ------------------------ 6.3/16.2 MB 7.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.6/16.2 MB 7.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 7.0/16.2 MB 7.7 MB/s eta 0:00:02
#    ------------------ --------------------- 7.4/16.2 MB 7.7 MB/s eta 0:00:02
#    ------------------- -------------------- 7.8/16.2 MB 7.8 MB/s eta 0:00:02
#    -------------------- ------------------- 8.1/16.2 MB 7.8 MB/s eta 0:00:02
#    --------------------- ------------------ 8.5/16.2 MB 7.8 MB/s eta 0:00:01
#    --------------------- ------------------ 8.9/16.2 MB 7.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 9.3/16.2 MB 7.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.7/16.2 MB 7.8 MB/s eta 0:00:01
#    ------------------------ --------------- 10.0/16.2 MB 7.8 MB/s eta 0:00:01
#    ------------------------- -------------- 10.4/16.2 MB 7.9 MB/s eta 0:00:01
#    -------------------------- ------------- 10.8/16.2 MB 7.9 MB/s eta 0:00:01
#    --------------------------- ------------ 11.1/16.2 MB 7.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.5/16.2 MB 7.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.9/16.2 MB 7.9 MB/s eta 0:00:01
#    ------------------------------ --------- 12.2/16.2 MB 7.9 MB/s eta 0:00:01
#    ------------------------------ --------- 12.5/16.2 MB 7.9 MB/s eta 0:00:01
#    ------------------------------- -------- 12.9/16.2 MB 8.0 MB/s eta 0:00:01
#    --------------------------------- ------ 13.4/16.2 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.8/16.2 MB 8.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.2/16.2 MB 8.2 MB/s eta 0:00:01
#    ------------------------------------ --- 14.6/16.2 MB 8.2 MB/s eta 0:00:01
#    ------------------------------------ --- 15.0/16.2 MB 8.2 MB/s eta 0:00:01
#    ------------------------------------- -- 15.4/16.2 MB 8.3 MB/s eta 0:00:01
#    -------------------------------------- - 15.8/16.2 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  16.2/16.2 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 16.2/16.2 MB 8.1 MB/s eta 0:00:00
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.0.0 pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.
#    customer_id first_name last_name                   email       phone  \
# 0            1       John       Doe    john.doe@example.com  1234567890
# 1            2       Jane     Smith  jane.smith@example.com  0987654321
#
#             created_at
# 0  2024-06-06 18:22:39
# 1  2024-06-06 18:22:39
#    account_id  customer_id account_type  balance           created_at
# 0           1            1     Checking     1000  2024-06-06 18:22:39
# 1           2            1      Savings     5000  2024-06-06 18:22:39
# 2           3            2     Checking     2000  2024-06-06 18:22:39
#    transaction_id  account_id  amount transaction_type            timestamp
# 0               1           1     500          Deposit  2024-06-06 18:22:39
# 1               2           1     200       Withdrawal  2024-06-06 18:22:39
# 2               3           2    1000          Deposit  2024-06-06 18:22:39
# 3               4           3    1500       Withdrawal  2024-06-06 18:22:39
# Potential Fraudulent Transactions:
#    transaction_id  account_id  amount transaction_type            timestamp
# 3               4           3    1500       Withdrawal  2024-06-06 18:22:39
# Total Transactions: 4
# Total Fraudulent Transactions: 1
# Percentage of Fraudulent Transactions: 25.00%
# Total Fraudulent Amount: $1500.00
